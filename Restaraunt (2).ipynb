# %% [markdown]
# ### ProblemStatement
#
# The basic idea of analyzing this dataset is to get a fair idea about the factors affecting the establishment of different types of the restaurant at different places, aggregate rating of each restaurant, With each day new restaurants opening the the industry hasn't been saturated yet and the demand is increasing day by day

# %% [markdown]
# #### Opportunity
#
# 1. From all the Data available, we can bring out some neat insights or conclusions such as
#
# - Which franchise has the highest number of Restaurants?
# - How many Restaurants are accepting online orders?
# - How many have a book table facility?
# - Which location has the highest number of Restaurants?
# - How many types of Restaurant types are there?
# - What is the most liked Restaurant type?
# - What is the Average cost for 2 persons?
# - What is the most liked Dish type?

# %%
# Dataframe Libraries
import pandas as pd
import numpy as np

#Vizualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Resturants.csv', sep=',', encoding='latin-1')

# %%
data.shape
# Out:
# (9551, 21)

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Adding data into new variable.

# %%
data_new = data.copy()

# %%
data_new.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
sns.heatmap(data_new.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analysis

# %% [markdown]
# 1. Which franchise has the highest number of Restaurants?

# %%
data_new_restraunt_names = data_new['Restaurant Name'].value_counts()

# %%
data_new_restraunt_names = pd.DataFrame(data_new_restraunt_names).head(10)

# %%
data_new_restraunt_names
# Out:
#                   Restaurant Name
# Cafe Coffee Day                83
# Domino's Pizza                 79
# Subway                         63
# Green Chick Chop               51
# McDonald's                     48
# Keventers                      34
# Pizza Hut                      30
# Giani                          29
# Baskin Robbins                 28
# Barbeque Nation                26

# %%
top_10 =pd.DataFrame(data_new['Restaurant Name'].value_counts().head(10))

# %%
pd.DataFrame(data_new['Restaurant Name'].value_counts().head(10))
# Out:
#                   Restaurant Name
# Cafe Coffee Day                83
# Domino's Pizza                 79
# Subway                         63
# Green Chick Chop               51
# McDonald's                     48
# Keventers                      34
# Pizza Hut                      30
# Giani                          29
# Baskin Robbins                 28
# Barbeque Nation                26

# %%
top_10.plot(kind = 'bar',color = 'b')
plt.ylabel('No of Restaraunts')
# Out:
# Text(0, 0.5, 'No of Restaraunts')

# %% [markdown]
# ### Question 2 : How many Restaurants are accepting online orders?

# %%
data_new.head(20)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
sns.countplot('Has Online delivery',data=data_new)
# Out:
# C:\Users\ashish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %%
pd.DataFrame(data_new['Has Online delivery'].value_counts())
# Out:
#      Has Online delivery
# No                  7100
# Yes                 2451

# %%
sns.countplot('Is delivering now',data=data_new)
# Out:
# C:\Users\ashish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Is delivering now', ylabel='count'>

# %%
pd.DataFrame(data_new['Is delivering now'].value_counts())
# Out:
#      Is delivering now
# No                9517
# Yes                 34

# %% [markdown]
# ### Analyis
#
# 1. There are about 2451 restaraunts which are accepting online orders out of which only 34 restaraunts are delivering online orders.

# %%
unique_value = data_new['Restaurant Name'].nunique()

# %%
print(unique_value)
# Out:
# 7446

# %% [markdown]
# ### Question 3 : How many have a book table facility?

# %%
sns.countplot('Has Table booking',data=data_new)
# Out:
# C:\Users\ashish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %%
data_new['Has Table booking'].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %% [markdown]
# ### There about 1158 restaraunts which accept Table Booking.

# %% [markdown]
# ### Question 4 :  Which location has the highest number of Restaurants?

# %%
top10_city =  pd.DataFrame(data_new['City'].value_counts().head(10))

# %%
top10_city
# Out:
#               City
# New Delhi     5473
# Gurgaon       1118
# Noida         1080
# Faridabad      251
# Ghaziabad       25
# Bhubaneshwar    21
# Amritsar        21
# Ahmedabad       21
# Lucknow         21
# Guwahati        21

# %%
top10_city.plot(kind = 'bar')
plt.ylabel('Highest Number of Restaraunts')
# Out:
# Text(0, 0.5, 'Highest Number of Restaraunts')

# %% [markdown]
# ### Question 5 :  How many types of Restaurant types are there?

# %%
myuniquelist = list(set(data_new['Cuisines']))

# %%
myuniquelist = pd.DataFrame(myuniquelist)

# %%
myuniquelist
# Out:
#                                                       0
# 0                                                   NaN
# 1              Persian, Arabian, Lebanese, North Indian
# 2                                          French, Kiwi
# 3                                     Kashmiri, Mughlai
# 4                                   Bar Food, Brazilian
# ...                                                 ...
# 1821         Fast Food, North Indian, Chinese, Desserts
# 1822                      Bakery, Chinese, North Indian
# 1823                         Breakfast, Diner, Sandwich
# 1824  North Indian, South Indian, Chinese, Fast Food...
# 1825  North Indian, Continental, Chinese, Japanese, ...
#
# [1826 rows x 1 columns]

# %%
data_new1['Cuisines'].value_counts().head(10)
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
list(set(data_new['Price range']))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### What is the Average cost for 2 persons?

# %%
data_new['Price range'].sum()/len(data_new['Price range'])/2
# Out:
# 0.9024185949115275

# %%
list(set(data_new['Currency']))
# Out:
# ['Botswana Pula(P)',
#  'Brazilian Real(R$)',
#  'Turkish Lira(TL)',
#  'Rand(R)',
#  'Indian Rupees(Rs.)',
#  'Indonesian Rupiah(IDR)',
#  'Qatari Rial(QR)',
#  'NewZealand($)',
#  'Emirati Diram(AED)',
#  'Pounds(\x8c£)',
#  'Sri Lankan Rupee(LKR)',
#  'Dollar($)']

# %%
data_new1 = data.copy()

# %%
data_new1['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %% [markdown]
# ### Data Analysis of the Questions
# 1. Which franchise has the highest number of Restaurants?
# - Answer: Cafe Coffee Day has the highest number of Restaurants
#
# 2. How many Restaurants are accepting online orders?
# - Answer: There are about 2451 restaraunts which are accepting online orders out of which only 34 restaraunts are delivering online orders, rest are take away's.
#
# 3. How many have a book table facility?
# - Answer: There about 1158 restaraunts which have a book table facility
#
# 4. Which location has the highest number of Restaurants?
# - Answer: New Delhi has the Highest Number of restaraunts followed by gurgoan and Noida
#
# 5. How many types of Restaurant types are there?
# - Answer:
#
# 6. What is the most liked Restaurant type?
# - Answer:
#
# 7. What is the Average cost for 2 persons?
# - Answer: The Average cost of 2 persons is 0.9024185949115275.
#
# 8. What is the most liked Dish type?
# - Answer:
